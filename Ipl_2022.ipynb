# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv('/content/IPLData.csv')

# %%
data.head()
# Out:
#        Player Name       Team Nationality Player_Type  Capped  Matches_Played  \
# 0   Shikhar Dhawan     Punjab      Indian      Batter       1           192.0
# 1    Shreyas Iyer     Kolkata      Indian      Batter       1            87.0
# 2   Faf Du Plessis  Bangalore    Overseas      Batter       1           100.0
# 3   Manish Pandey     Lucknow      Indian      Batter       1           154.0
# 4  Shimron Hetmyer  Rajasthan    Overseas      Batter       1            31.0
#
#      Runs  Average  Strike_Rate  Wickets  Bowling_average  Economy  \
# 0  5783.0    34.63       126.60      4.0             16.5     8.25
# 1  2375.0    31.67       123.96      NaN              NaN      NaN
# 2  2935.0    34.94       131.09      NaN              NaN      NaN
# 3  3560.0    30.69       121.83      NaN              NaN      NaN
# 4   517.0    25.85       151.17      NaN              NaN      NaN
#
#    Bowling_Strike_Rate  Catches  Run_outs  Stumps
# 0                 12.0      NaN       NaN     NaN
# 1                  NaN      NaN       NaN     NaN
# 2                  NaN      NaN       NaN     NaN
# 3                  NaN      NaN       NaN     NaN
# 4                  NaN      NaN       NaN     NaN

# %%
data.describe()
# Out:
#            Capped  Matches_Played         Runs     Average  Strike_Rate  \
# count  235.000000      215.000000   165.000000  161.000000   163.000000
# mean     0.838298       43.897674   840.575758   21.792391   121.009939
# std      0.561802       48.695302  1270.341831   11.664156    30.739189
# min      0.000000        1.000000     0.000000    0.000000     0.000000
# 25%      0.500000       11.500000    67.000000   13.800000   112.635000
# 50%      1.000000       25.000000   289.000000   22.410000   128.630000
# 75%      1.000000       56.000000   954.000000   29.300000   137.550000
# max      2.000000      220.000000  6283.000000   58.500000   190.240000
#
#           Wickets  Bowling_average     Economy  Bowling_Strike_Rate  \
# count  140.000000       135.000000  143.000000           119.000000
# mean    31.485714        32.907185    8.223182            24.686134
# std     36.872420        18.191441    1.223541            12.982049
# min      0.000000         0.000000    5.360000             0.000000
# 25%      6.000000        23.025000    7.390000            18.495000
# 50%     19.500000        29.070000    8.190000            21.750000
# 75%     40.500000        36.030000    8.785000            26.190000
# max    167.000000       153.000000   13.120000           108.000000
#
#           Catches   Run_outs     Stumps
# count   27.000000  27.000000  27.000000
# mean    30.962963   3.444444   6.259259
# std     34.544822   5.010246   9.928950
# min      0.000000   0.000000   0.000000
# 25%      3.500000   0.000000   0.000000
# 50%     19.000000   1.000000   2.000000
# 75%     51.500000   4.000000   7.000000
# max    126.000000  21.000000  39.000000

# %%
data.isna().sum()
# Out:
# Player Name              0
# Team                     0
# Nationality              0
# Player_Type              0
# Capped                   0
# Matches_Played          20
# Runs                    70
# Average                 74
# Strike_Rate             72
# Wickets                 95
# Bowling_average        100
# Economy                 92
# Bowling_Strike_Rate    116
# Catches                208
# Run_outs               208
# Stumps                 208
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 235 entries, 0 to 234
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Player Name          235 non-null    object
#  1   Team                 235 non-null    object
#  2   Nationality          235 non-null    object
#  3   Player_Type          235 non-null    object
#  4   Capped               235 non-null    int64
#  5   Matches_Played       215 non-null    float64
#  6   Runs                 165 non-null    float64
#  7   Average              161 non-null    float64
#  8   Strike_Rate          163 non-null    float64
#  9   Wickets              140 non-null    float64
#  10  Bowling_average      135 non-null    float64
#  11  Economy              143 non-null    float64
#  12  Bowling_Strike_Rate  119 non-null    float64
#  13  Catches              27 non-null     float64
#  14  Run_outs             27 non-null     float64
#  15  Stumps               27 non-null     float64
# dtypes: float64(11), int64(1), object(4)
# memory usage: 29.5+ KB

# %% [markdown]
# # Cleaning the data

# %%
batters=data.loc[(data["Player_Type"]=="Batter")]
batters_new=batters.loc[(batters["Capped"]==1)]
Capped_Batters=batters_new[['Player Name','Matches_Played','Team','Nationality','Runs','Average','Strike_Rate']]

# %%
Capped_Batters.head()
# Out:
#        Player Name  Matches_Played       Team Nationality    Runs  Average  \
# 0   Shikhar Dhawan           192.0     Punjab      Indian  5783.0    34.63
# 1    Shreyas Iyer             87.0    Kolkata      Indian  2375.0    31.67
# 2   Faf Du Plessis           100.0  Bangalore    Overseas  2935.0    34.94
# 3   Manish Pandey            154.0    Lucknow      Indian  3560.0    30.69
# 4  Shimron Hetmyer            31.0  Rajasthan    Overseas   517.0    25.85
#
#    Strike_Rate
# 0       126.60
# 1       123.96
# 2       131.09
# 3       121.83
# 4       151.17

# %%
Capped_Batters.tail()
# Out:
#           Player Name  Matches_Played       Team Nationality    Runs  Average  \
# 220    Mayank Agarwal           100.0     Punjab      Indian  2135.0    23.46
# 225  Suryakumar Yadav           115.0     Mumbai      Indian  2341.0    28.90
# 228  Yashasvi Jaiswal            13.0  Rajasthan      Indian   289.0    22.23
# 229      Shubman Gill            58.0    Gujarat      Indian  1417.0    31.49
# 231   Ruturaj Gaikwad            22.0    Chennai      Indian   839.0    46.61
#
#      Strike_Rate
# 220       135.73
# 225       135.71
# 228       136.32
# 229       123.00
# 231       132.13

# %%
bowlers=data.loc[(data["Player_Type"]== "Bowler ")]
bowlers_new=bowlers.loc[(bowlers["Capped"] ==1)]
Capped_Bowlers=bowlers_new[['Player Name','Matches_Played','Team','Nationality','Wickets','Bowling_average','Bowling_Strike_Rate','Economy']]

# %%
Capped_Bowlers.head()
# Out:
#         Player Name  Matches_Played       Team Nationality  Wickets  \
# 36   Kagiso Rabada             50.0     Punjab    Overseas     76.0
# 37     Trent Boult             62.0  Rajasthan    Overseas     76.0
# 38  Mohammad Shami             77.0    Gujarat      Indian     79.0
# 39      T Natarajan            24.0  Hyderabad      Indian     20.0
# 40   Deepak Chahar             63.0    Chennai      Indian     59.0
#
#     Bowling_average  Bowling_Strike_Rate  Economy
# 36            20.53                15.00     8.21
# 37            26.09                18.64     8.40
# 38            30.41                21.14     8.63
# 39            34.40                25.05     8.24
# 40            29.19                22.44     7.80

# %%
Capped_Bowlers.tail()
# Out:
#             Player Name  Matches_Played     Team Nationality  Wickets  \
# 210     Arshdeep Singh             23.0   Punjab      Indian     30.0
# 214  Varun Chakravarthy            31.0  Kolkata      Indian     36.0
# 215      Jasprit Bumrah           106.0   Mumbai      Indian    130.0
# 230        Ravi Bishnoi            23.0  Lucknow      Indian     24.0
# 234       Anrich Nortje            24.0    Delhi    Overseas     34.0
#
#      Bowling_average  Bowling_Strike_Rate  Economy
# 210            22.30                15.23     8.78
# 214            23.31                20.50     6.82
# 215            23.05                18.63     7.42
# 230            25.25                21.75     6.97
# 234            20.56                16.12     7.65

# %%
Allrounders=data.loc[(data["Player_Type"]== "Allrounder")]
Allrounders_new=Allrounders.loc[(Allrounders["Capped"] == 1)]
Capped_Allrounders=Allrounders_new[['Player Name','Matches_Played','Team','Runs','Average','Strike_Rate','Nationality','Wickets','Bowling_average','Bowling_Strike_Rate','Economy']]

# %%
Capped_Allrounders.head()
# Out:
#               Player Name  Matches_Played       Team    Runs  Average  \
# 127  Ravichandran Ashwin            167.0  Rajasthan   456.0    11.12
# 128          Pat Cummins             37.0    Kolkata   316.0    19.75
# 129         Dwayne Bravo            151.0    Chennai  1537.0    22.94
# 130          Nitish Rana             77.0    Kolkata  1820.0    28.00
# 131          Jason Holder            26.0    Lucknow   189.0    14.54
#
#      Strike_Rate Nationality  Wickets  Bowling_average  Bowling_Strike_Rate  \
# 127       109.88      Indian    145.0            27.80                24.12
# 128       140.44    Overseas     38.0            30.13                21.95
# 129       130.25    Overseas    167.0            24.32                17.44
# 130       132.46      Indian      7.0            22.00                16.43
# 131       121.15    Overseas     35.0            22.46                16.43
#
#      Economy
# 127     6.91
# 128     8.24
# 129     8.36
# 130     8.03
# 131     8.20

# %%
Capped_Allrounders.tail()
# Out:
#          Player Name  Matches_Played     Team    Runs  Average  Strike_Rate  \
# 223        Moeen Ali            34.0  Chennai   666.0    22.97       146.37
# 224   Venkatesh Iyer            10.0  Kolkata   370.0    41.11       128.47
# 226       Axar Patel           109.0    Delhi   953.0    17.30       125.33
# 232    Sunil Narine            134.0  Kolkata   954.0    15.64       161.69
# 233  Kieron Pollard            178.0   Mumbai  3268.0    29.98       149.77
#
#     Nationality  Wickets  Bowling_average  Bowling_Strike_Rate  Economy
# 223    Overseas     16.0            29.31                25.69     6.85
# 224      Indian      3.0            23.00                17.00     8.12
# 226      Indian     95.0            29.07                24.16     7.22
# 232    Overseas    143.0            24.53                21.83     6.74
# 233    Overseas     65.0            31.62                21.60     8.78

# %%
Keepers=data.loc[(data["Player_Type"]== "Keeper")]
Keepers_new=Keepers.loc[(Keepers["Capped"] == 1)]
Capped_Keepers=Keepers_new[['Player Name','Matches_Played','Team','Runs','Average','Strike_Rate','Nationality','Catches','Run_outs','Stumps']]

# %%
Capped_Keepers.head()
# Out:
#          Player Name  Matches_Played       Team    Runs  Average  Strike_Rate  \
# 105  Quinton De Kock            77.0    Lucknow  2256.0     31.3        130.9
# 106    Ambati Rayudu           175.0    Chennai  3916.0     29.4        127.5
# 107     Ishan Kishan            61.0     Mumbai  1452.0     28.5        136.3
# 108   Jonny Bairstow            28.0     Punjab  1038.0     41.5        142.2
# 109   Dinesh Karthik           213.0  Bangalore  4046.0     25.8        129.7
#
#     Nationality  Catches  Run_outs  Stumps
# 105    Overseas     53.0       0.0    14.0
# 106      Indian     58.0      12.0     2.0
# 107      Indian     19.0       1.0     2.0
# 108    Overseas     18.0       1.0     4.0
# 109      Indian    123.0      14.0    32.0

# %%
Capped_Keepers.tail()
# Out:
#        Player Name  Matches_Played       Team    Runs  Average  Strike_Rate  \
# 121   Vishnu Vinod             3.0  Hyderabad    19.0     6.30        73.10
# 206  Rishabh Pant             84.0      Delhi  2498.0    35.18       147.46
# 209   Sanju Samson           121.0  Rajasthan  3068.0    29.22       134.21
# 213       MS Dhoni           220.0    Chennai  4746.0    39.50       135.80
# 219     Jos Butler            65.0  Rajasthan  1968.0    35.14       150.00
#
#     Nationality  Catches  Run_outs  Stumps
# 121      Indian      0.0       0.0     2.0
# 206      Indian     56.0       5.0    14.0
# 209      Indian     59.0       8.0    10.0
# 213      Indian    126.0      21.0    39.0
# 219    Overseas     34.0       3.0     1.0

# %%
Capped_Batters=Capped_Batters.fillna(0)
print(Capped_Batters.isna().sum())
# Out:
# Player Name       0
# Matches_Played    0
# Team              0
# Nationality       0
# Runs              0
# Average           0
# Strike_Rate       0
# dtype: int64

# %%
Capped_Bowlers=Capped_Bowlers.fillna(0)
print(Capped_Batters.isna().sum())
# Out:
# Player Name       0
# Matches_Played    0
# Team              0
# Nationality       0
# Runs              0
# Average           0
# Strike_Rate       0
# dtype: int64

# %%
Capped_Allrounders=Capped_Allrounders.fillna(0)
print(Capped_Allrounders.isna().sum())
# Out:
# Player Name            0
# Matches_Played         0
# Team                   0
# Runs                   0
# Average                0
# Strike_Rate            0
# Nationality            0
# Wickets                0
# Bowling_average        0
# Bowling_Strike_Rate    0
# Economy                0
# dtype: int64

# %%
Capped_Keepers=Capped_Keepers.fillna(0)
print(Capped_Keepers.isna().sum())
# Out:
# Player Name       0
# Matches_Played    0
# Team              0
# Runs              0
# Average           0
# Strike_Rate       0
# Nationality       0
# Catches           0
# Run_outs          0
# Stumps            0
# dtype: int64

# %% [markdown]
# # Initial Analysis

# %% [markdown]
# # **Batsman**

# %%
top_batters=Capped_Batters.loc[(Capped_Batters["Average"]>=32.0)]
top_batters_average=top_batters.sort_values('Average',ascending=False)
top_batters_Strike_Rate=top_batters.sort_values('Strike_Rate',ascending=False)
top_batters_runs=top_batters.sort_values('Runs',ascending=False)
top_batters_matches=top_batters.sort_values('Matches_Played',ascending=False)

# %%
top_batters_average
# Out:
#          Player Name  Matches_Played       Team Nationality    Runs  Average  \
# 212        KL Rahul             94.0    Lucknow      Indian  3273.0    47.43
# 231  Ruturaj Gaikwad            22.0    Chennai      Indian   839.0    46.61
# 19     David Warner            150.0      Delhi    Overseas  5449.0    41.60
# 207  Kane Williamson            63.0  Hyderabad    Overseas  1885.0    40.11
# 208      Virat Kohli           207.0  Bangalore      Indian  6283.0    37.40
# 2     Faf Du Plessis           100.0  Bangalore    Overseas  2935.0    34.94
# 0     Shikhar Dhawan           192.0     Punjab      Indian  5783.0    34.63
# 26     David Miller             89.0    Gujarat    Overseas  1974.0    32.90
#
#      Strike_Rate
# 212       136.38
# 231       132.13
# 19        139.97
# 207       131.27
# 208       129.95
# 2         131.09
# 0         126.60
# 26        136.51

# %%
top_batters_Strike_Rate
# Out:
#          Player Name  Matches_Played       Team Nationality    Runs  Average  \
# 19     David Warner            150.0      Delhi    Overseas  5449.0    41.60
# 26     David Miller             89.0    Gujarat    Overseas  1974.0    32.90
# 212        KL Rahul             94.0    Lucknow      Indian  3273.0    47.43
# 231  Ruturaj Gaikwad            22.0    Chennai      Indian   839.0    46.61
# 207  Kane Williamson            63.0  Hyderabad    Overseas  1885.0    40.11
# 2     Faf Du Plessis           100.0  Bangalore    Overseas  2935.0    34.94
# 208      Virat Kohli           207.0  Bangalore      Indian  6283.0    37.40
# 0     Shikhar Dhawan           192.0     Punjab      Indian  5783.0    34.63
#
#      Strike_Rate
# 19        139.97
# 26        136.51
# 212       136.38
# 231       132.13
# 207       131.27
# 2         131.09
# 208       129.95
# 0         126.60

# %%
top_batters_matches
# Out:
#          Player Name  Matches_Played       Team Nationality    Runs  Average  \
# 208      Virat Kohli           207.0  Bangalore      Indian  6283.0    37.40
# 0     Shikhar Dhawan           192.0     Punjab      Indian  5783.0    34.63
# 19     David Warner            150.0      Delhi    Overseas  5449.0    41.60
# 2     Faf Du Plessis           100.0  Bangalore    Overseas  2935.0    34.94
# 212        KL Rahul             94.0    Lucknow      Indian  3273.0    47.43
# 26     David Miller             89.0    Gujarat    Overseas  1974.0    32.90
# 207  Kane Williamson            63.0  Hyderabad    Overseas  1885.0    40.11
# 231  Ruturaj Gaikwad            22.0    Chennai      Indian   839.0    46.61
#
#      Strike_Rate
# 208       129.95
# 0         126.60
# 19        139.97
# 2         131.09
# 212       136.38
# 26        136.51
# 207       131.27
# 231       132.13

# %%
top_batters_runs
# Out:
#          Player Name  Matches_Played       Team Nationality    Runs  Average  \
# 208      Virat Kohli           207.0  Bangalore      Indian  6283.0    37.40
# 0     Shikhar Dhawan           192.0     Punjab      Indian  5783.0    34.63
# 19     David Warner            150.0      Delhi    Overseas  5449.0    41.60
# 212        KL Rahul             94.0    Lucknow      Indian  3273.0    47.43
# 2     Faf Du Plessis           100.0  Bangalore    Overseas  2935.0    34.94
# 26     David Miller             89.0    Gujarat    Overseas  1974.0    32.90
# 207  Kane Williamson            63.0  Hyderabad    Overseas  1885.0    40.11
# 231  Ruturaj Gaikwad            22.0    Chennai      Indian   839.0    46.61
#
#      Strike_Rate
# 208       129.95
# 0         126.60
# 19        139.97
# 212       136.38
# 2         131.09
# 26        136.51
# 207       131.27
# 231       132.13

# %% [markdown]
# **# lets take 3 batsman to make the top 11 fantasy**
#  1. **David Warner**
#  2. **KL Rahul**
#  3. **Virat Kohli**
#  4. **Ruturaj Gaikwad**

# %% [markdown]
# # ***Bowlers***

# %%
top_bowlers=Capped_Bowlers.loc[(Capped_Bowlers["Bowling_average"]<=25.0)]
top_bowlers_average=top_bowlers.sort_values('Bowling_average')
top_bowlers_economy=top_bowlers.sort_values('Economy')
top_bowlers_Strike_Rate=top_bowlers.sort_values('Bowling_Strike_Rate')
top_bowlers_Wickets=top_bowlers.sort_values('Wickets', ascending=False)
top_bowlers_matches=top_bowlers.sort_values('Matches_Played', ascending=False)

# %%
top_bowlers_average.head(10)
# Out:
#              Player Name  Matches_Played       Team Nationality  Wickets  \
# 83            Rasikh Dar             1.0    Kolkata      Indian      1.0
# 87           Sean Abbott             2.0  Hyderabad    Overseas      0.0
# 101         Kuldip Yadav             1.0  Rajasthan      Indian      0.0
# 88        Alzarri Joseph             3.0    Gujarat    Overseas      6.0
# 93          Lungi Ngidi             14.0     Delhi     Overseas     25.0
# 36        Kagiso Rabada             50.0     Punjab    Overseas     76.0
# 234        Anrich Nortje            24.0      Delhi    Overseas     34.0
# 103  Nathan Coulter-Nile            38.0  Rajasthan    Overseas     48.0
# 50     Yuzvendra Chahal            114.0  Rajasthan      Indian    139.0
# 210      Arshdeep Singh             23.0     Punjab      Indian     30.0
#
#      Bowling_average  Bowling_Strike_Rate  Economy
# 83              0.00                 0.00    10.50
# 87              0.00                 0.00    11.40
# 101             0.00                 0.00     8.00
# 88             14.50                 8.67    10.04
# 93             17.92                12.96     8.30
# 36             20.53                15.00     8.21
# 234            20.56                16.12     7.65
# 103            21.92                17.48     7.52
# 50             22.28                17.61     7.59
# 210            22.30                15.23     8.78

# %%
top_bowlers_economy
# Out:
#              Player Name  Matches_Played       Team Nationality  Wickets  \
# 214   Varun Chakravarthy            31.0    Kolkata      Indian     36.0
# 215       Jasprit Bumrah           106.0     Mumbai      Indian    130.0
# 103  Nathan Coulter-Nile            38.0  Rajasthan    Overseas     48.0
# 50     Yuzvendra Chahal            114.0  Rajasthan      Indian    139.0
# 234        Anrich Nortje            24.0      Delhi    Overseas     34.0
# 101         Kuldip Yadav             1.0  Rajasthan      Indian      0.0
# 36        Kagiso Rabada             50.0     Punjab    Overseas     76.0
# 93          Lungi Ngidi             14.0     Delhi     Overseas     25.0
# 65        Khaleel Ahmed             24.0      Delhi      Indian     32.0
# 210      Arshdeep Singh             23.0     Punjab      Indian     30.0
# 88        Alzarri Joseph             3.0    Gujarat    Overseas      6.0
# 83            Rasikh Dar             1.0    Kolkata      Indian      1.0
# 87           Sean Abbott             2.0  Hyderabad    Overseas      0.0
#
#      Bowling_average  Bowling_Strike_Rate  Economy
# 214            23.31                20.50     6.82
# 215            23.05                18.63     7.42
# 103            21.92                17.48     7.52
# 50             22.28                17.61     7.59
# 234            20.56                16.12     7.65
# 101             0.00                 0.00     8.00
# 36             20.53                15.00     8.21
# 93             17.92                12.96     8.30
# 65             24.56                16.97     8.69
# 210            22.30                15.23     8.78
# 88             14.50                 8.67    10.04
# 83              0.00                 0.00    10.50
# 87              0.00                 0.00    11.40

# %%
top_bowlers_Strike_Rate
# Out:
#              Player Name  Matches_Played       Team Nationality  Wickets  \
# 83            Rasikh Dar             1.0    Kolkata      Indian      1.0
# 87           Sean Abbott             2.0  Hyderabad    Overseas      0.0
# 101         Kuldip Yadav             1.0  Rajasthan      Indian      0.0
# 88        Alzarri Joseph             3.0    Gujarat    Overseas      6.0
# 93          Lungi Ngidi             14.0     Delhi     Overseas     25.0
# 36        Kagiso Rabada             50.0     Punjab    Overseas     76.0
# 210      Arshdeep Singh             23.0     Punjab      Indian     30.0
# 234        Anrich Nortje            24.0      Delhi    Overseas     34.0
# 65        Khaleel Ahmed             24.0      Delhi      Indian     32.0
# 103  Nathan Coulter-Nile            38.0  Rajasthan    Overseas     48.0
# 50     Yuzvendra Chahal            114.0  Rajasthan      Indian    139.0
# 215       Jasprit Bumrah           106.0     Mumbai      Indian    130.0
# 214   Varun Chakravarthy            31.0    Kolkata      Indian     36.0
#
#      Bowling_average  Bowling_Strike_Rate  Economy
# 83              0.00                 0.00    10.50
# 87              0.00                 0.00    11.40
# 101             0.00                 0.00     8.00
# 88             14.50                 8.67    10.04
# 93             17.92                12.96     8.30
# 36             20.53                15.00     8.21
# 210            22.30                15.23     8.78
# 234            20.56                16.12     7.65
# 65             24.56                16.97     8.69
# 103            21.92                17.48     7.52
# 50             22.28                17.61     7.59
# 215            23.05                18.63     7.42
# 214            23.31                20.50     6.82

# %%
top_bowlers_Wickets
# Out:
#              Player Name  Matches_Played       Team Nationality  Wickets  \
# 50     Yuzvendra Chahal            114.0  Rajasthan      Indian    139.0
# 215       Jasprit Bumrah           106.0     Mumbai      Indian    130.0
# 36        Kagiso Rabada             50.0     Punjab    Overseas     76.0
# 103  Nathan Coulter-Nile            38.0  Rajasthan    Overseas     48.0
# 214   Varun Chakravarthy            31.0    Kolkata      Indian     36.0
# 234        Anrich Nortje            24.0      Delhi    Overseas     34.0
# 65        Khaleel Ahmed             24.0      Delhi      Indian     32.0
# 210      Arshdeep Singh             23.0     Punjab      Indian     30.0
# 93          Lungi Ngidi             14.0     Delhi     Overseas     25.0
# 88        Alzarri Joseph             3.0    Gujarat    Overseas      6.0
# 83            Rasikh Dar             1.0    Kolkata      Indian      1.0
# 87           Sean Abbott             2.0  Hyderabad    Overseas      0.0
# 101         Kuldip Yadav             1.0  Rajasthan      Indian      0.0
#
#      Bowling_average  Bowling_Strike_Rate  Economy
# 50             22.28                17.61     7.59
# 215            23.05                18.63     7.42
# 36             20.53                15.00     8.21
# 103            21.92                17.48     7.52
# 214            23.31                20.50     6.82
# 234            20.56                16.12     7.65
# 65             24.56                16.97     8.69
# 210            22.30                15.23     8.78
# 93             17.92                12.96     8.30
# 88             14.50                 8.67    10.04
# 83              0.00                 0.00    10.50
# 87              0.00                 0.00    11.40
# 101             0.00                 0.00     8.00

# %% [markdown]
# **# lets take 4 bowlers to make the top 11 fantasy**
#
# 1.   **Arshdeep Singh**
# 2.   **Kagiso Rabada**
# 3.   **Jasprit Bumrah**
# 4.   **Yuzvendra Chahal**

# %% [markdown]
# # **All-Rounders**

# %%
top_allrounders=Capped_Allrounders.loc[(Capped_Allrounders["Strike_Rate"]>=140.0)]
top_allrounders_average=top_allrounders.sort_values('Average',ascending=False)
top_allrounders_strike_rate=top_allrounders.sort_values('Strike_Rate',ascending=False)
top_allrounders_runs=top_allrounders.sort_values('Runs',ascending=False)
top_allrounders_matches=top_allrounders.sort_values('Matches_Played',ascending=False)
top_allrounders_bowling_average=top_allrounders.sort_values('Bowling_average')
top_allrounders_bowling_strike_rate=top_allrounders.sort_values('Bowling_Strike_Rate')
top_allrounders_wickets=top_allrounders.sort_values('Wickets',ascending=False)
top_allrounders_economy=top_allrounders.sort_values('Economy')

# %%
top_allrounders_average
# Out:
#          Player Name  Matches_Played       Team    Runs  Average  Strike_Rate  \
# 233  Kieron Pollard            178.0     Mumbai  3268.0    29.98       149.77
# 204    Andre Russell            84.0    Kolkata  1700.0    29.31       178.57
# 211    Hardik Pandya            92.0    Gujarat  1476.0    27.33       153.91
# 218     Glen Maxwell            97.0  Bangalore  2018.0    25.23       151.84
# 223        Moeen Ali            34.0    Chennai   666.0    22.97       146.37
# 128     Pat Cummins             37.0    Kolkata   316.0    19.75       140.44
# 232    Sunil Narine            134.0    Kolkata   954.0    15.64       161.69
# 165     Jofra Archer            35.0     Mumbai   195.0    15.00       157.26
# 195   Mohammad Nabi             17.0    Kolkata   180.0    15.00       151.26
# 154       K Gowtham             24.0    Lucknow   186.0    14.31       169.09
# 202       Aman Khan              5.0    Kolkata    40.0    13.30       148.10
#
#     Nationality  Wickets  Bowling_average  Bowling_Strike_Rate  Economy
# 233    Overseas     65.0            31.62                21.60     8.78
# 204    Overseas     72.0            26.40                17.51     9.05
# 211      Indian     42.0            31.26                20.69     9.07
# 218    Overseas     22.0            41.59                29.18     8.55
# 223    Overseas     16.0            29.31                25.69     6.85
# 128    Overseas     38.0            30.13                21.95     8.24
# 232    Overseas    143.0            24.53                21.83     6.74
# 165    Overseas     46.0            21.33                17.93     7.13
# 195    Overseas     13.0            31.38                26.38     7.14
# 154      Indian     13.0            43.23                31.38     8.26
# 202      Indian      0.0             0.00                 0.00     7.00

# %%
top_allrounders_strike_rate
# Out:
#          Player Name  Matches_Played       Team    Runs  Average  Strike_Rate  \
# 204    Andre Russell            84.0    Kolkata  1700.0    29.31       178.57
# 154       K Gowtham             24.0    Lucknow   186.0    14.31       169.09
# 232    Sunil Narine            134.0    Kolkata   954.0    15.64       161.69
# 165     Jofra Archer            35.0     Mumbai   195.0    15.00       157.26
# 211    Hardik Pandya            92.0    Gujarat  1476.0    27.33       153.91
# 218     Glen Maxwell            97.0  Bangalore  2018.0    25.23       151.84
# 195   Mohammad Nabi             17.0    Kolkata   180.0    15.00       151.26
# 233  Kieron Pollard            178.0     Mumbai  3268.0    29.98       149.77
# 202       Aman Khan              5.0    Kolkata    40.0    13.30       148.10
# 223        Moeen Ali            34.0    Chennai   666.0    22.97       146.37
# 128     Pat Cummins             37.0    Kolkata   316.0    19.75       140.44
#
#     Nationality  Wickets  Bowling_average  Bowling_Strike_Rate  Economy
# 204    Overseas     72.0            26.40                17.51     9.05
# 154      Indian     13.0            43.23                31.38     8.26
# 232    Overseas    143.0            24.53                21.83     6.74
# 165    Overseas     46.0            21.33                17.93     7.13
# 211      Indian     42.0            31.26                20.69     9.07
# 218    Overseas     22.0            41.59                29.18     8.55
# 195    Overseas     13.0            31.38                26.38     7.14
# 233    Overseas     65.0            31.62                21.60     8.78
# 202      Indian      0.0             0.00                 0.00     7.00
# 223    Overseas     16.0            29.31                25.69     6.85
# 128    Overseas     38.0            30.13                21.95     8.24

# %%
top_allrounders_runs
# Out:
#          Player Name  Matches_Played       Team    Runs  Average  Strike_Rate  \
# 233  Kieron Pollard            178.0     Mumbai  3268.0    29.98       149.77
# 218     Glen Maxwell            97.0  Bangalore  2018.0    25.23       151.84
# 204    Andre Russell            84.0    Kolkata  1700.0    29.31       178.57
# 211    Hardik Pandya            92.0    Gujarat  1476.0    27.33       153.91
# 232    Sunil Narine            134.0    Kolkata   954.0    15.64       161.69
# 223        Moeen Ali            34.0    Chennai   666.0    22.97       146.37
# 128     Pat Cummins             37.0    Kolkata   316.0    19.75       140.44
# 165     Jofra Archer            35.0     Mumbai   195.0    15.00       157.26
# 154       K Gowtham             24.0    Lucknow   186.0    14.31       169.09
# 195   Mohammad Nabi             17.0    Kolkata   180.0    15.00       151.26
# 202       Aman Khan              5.0    Kolkata    40.0    13.30       148.10
#
#     Nationality  Wickets  Bowling_average  Bowling_Strike_Rate  Economy
# 233    Overseas     65.0            31.62                21.60     8.78
# 218    Overseas     22.0            41.59                29.18     8.55
# 204    Overseas     72.0            26.40                17.51     9.05
# 211      Indian     42.0            31.26                20.69     9.07
# 232    Overseas    143.0            24.53                21.83     6.74
# 223    Overseas     16.0            29.31                25.69     6.85
# 128    Overseas     38.0            30.13                21.95     8.24
# 165    Overseas     46.0            21.33                17.93     7.13
# 154      Indian     13.0            43.23                31.38     8.26
# 195    Overseas     13.0            31.38                26.38     7.14
# 202      Indian      0.0             0.00                 0.00     7.00

# %%
top_allrounders_matches
# Out:
#          Player Name  Matches_Played       Team    Runs  Average  Strike_Rate  \
# 233  Kieron Pollard            178.0     Mumbai  3268.0    29.98       149.77
# 232    Sunil Narine            134.0    Kolkata   954.0    15.64       161.69
# 218     Glen Maxwell            97.0  Bangalore  2018.0    25.23       151.84
# 211    Hardik Pandya            92.0    Gujarat  1476.0    27.33       153.91
# 204    Andre Russell            84.0    Kolkata  1700.0    29.31       178.57
# 128     Pat Cummins             37.0    Kolkata   316.0    19.75       140.44
# 165     Jofra Archer            35.0     Mumbai   195.0    15.00       157.26
# 223        Moeen Ali            34.0    Chennai   666.0    22.97       146.37
# 154       K Gowtham             24.0    Lucknow   186.0    14.31       169.09
# 195   Mohammad Nabi             17.0    Kolkata   180.0    15.00       151.26
# 202       Aman Khan              5.0    Kolkata    40.0    13.30       148.10
#
#     Nationality  Wickets  Bowling_average  Bowling_Strike_Rate  Economy
# 233    Overseas     65.0            31.62                21.60     8.78
# 232    Overseas    143.0            24.53                21.83     6.74
# 218    Overseas     22.0            41.59                29.18     8.55
# 211      Indian     42.0            31.26                20.69     9.07
# 204    Overseas     72.0            26.40                17.51     9.05
# 128    Overseas     38.0            30.13                21.95     8.24
# 165    Overseas     46.0            21.33                17.93     7.13
# 223    Overseas     16.0            29.31                25.69     6.85
# 154      Indian     13.0            43.23                31.38     8.26
# 195    Overseas     13.0            31.38                26.38     7.14
# 202      Indian      0.0             0.00                 0.00     7.00

# %%
top_allrounders_bowling_average
# Out:
#          Player Name  Matches_Played       Team    Runs  Average  Strike_Rate  \
# 202       Aman Khan              5.0    Kolkata    40.0    13.30       148.10
# 165     Jofra Archer            35.0     Mumbai   195.0    15.00       157.26
# 232    Sunil Narine            134.0    Kolkata   954.0    15.64       161.69
# 204    Andre Russell            84.0    Kolkata  1700.0    29.31       178.57
# 223        Moeen Ali            34.0    Chennai   666.0    22.97       146.37
# 128     Pat Cummins             37.0    Kolkata   316.0    19.75       140.44
# 211    Hardik Pandya            92.0    Gujarat  1476.0    27.33       153.91
# 195   Mohammad Nabi             17.0    Kolkata   180.0    15.00       151.26
# 233  Kieron Pollard            178.0     Mumbai  3268.0    29.98       149.77
# 218     Glen Maxwell            97.0  Bangalore  2018.0    25.23       151.84
# 154       K Gowtham             24.0    Lucknow   186.0    14.31       169.09
#
#     Nationality  Wickets  Bowling_average  Bowling_Strike_Rate  Economy
# 202      Indian      0.0             0.00                 0.00     7.00
# 165    Overseas     46.0            21.33                17.93     7.13
# 232    Overseas    143.0            24.53                21.83     6.74
# 204    Overseas     72.0            26.40                17.51     9.05
# 223    Overseas     16.0            29.31                25.69     6.85
# 128    Overseas     38.0            30.13                21.95     8.24
# 211      Indian     42.0            31.26                20.69     9.07
# 195    Overseas     13.0            31.38                26.38     7.14
# 233    Overseas     65.0            31.62                21.60     8.78
# 218    Overseas     22.0            41.59                29.18     8.55
# 154      Indian     13.0            43.23                31.38     8.26

# %%
top_allrounders_bowling_strike_rate
# Out:
#          Player Name  Matches_Played       Team    Runs  Average  Strike_Rate  \
# 202       Aman Khan              5.0    Kolkata    40.0    13.30       148.10
# 204    Andre Russell            84.0    Kolkata  1700.0    29.31       178.57
# 165     Jofra Archer            35.0     Mumbai   195.0    15.00       157.26
# 211    Hardik Pandya            92.0    Gujarat  1476.0    27.33       153.91
# 233  Kieron Pollard            178.0     Mumbai  3268.0    29.98       149.77
# 232    Sunil Narine            134.0    Kolkata   954.0    15.64       161.69
# 128     Pat Cummins             37.0    Kolkata   316.0    19.75       140.44
# 223        Moeen Ali            34.0    Chennai   666.0    22.97       146.37
# 195   Mohammad Nabi             17.0    Kolkata   180.0    15.00       151.26
# 218     Glen Maxwell            97.0  Bangalore  2018.0    25.23       151.84
# 154       K Gowtham             24.0    Lucknow   186.0    14.31       169.09
#
#     Nationality  Wickets  Bowling_average  Bowling_Strike_Rate  Economy
# 202      Indian      0.0             0.00                 0.00     7.00
# 204    Overseas     72.0            26.40                17.51     9.05
# 165    Overseas     46.0            21.33                17.93     7.13
# 211      Indian     42.0            31.26                20.69     9.07
# 233    Overseas     65.0            31.62                21.60     8.78
# 232    Overseas    143.0            24.53                21.83     6.74
# 128    Overseas     38.0            30.13                21.95     8.24
# 223    Overseas     16.0            29.31                25.69     6.85
# 195    Overseas     13.0            31.38                26.38     7.14
# 218    Overseas     22.0            41.59                29.18     8.55
# 154      Indian     13.0            43.23                31.38     8.26

# %%
top_allrounders_wickets
# Out:
#          Player Name  Matches_Played       Team    Runs  Average  Strike_Rate  \
# 232    Sunil Narine            134.0    Kolkata   954.0    15.64       161.69
# 204    Andre Russell            84.0    Kolkata  1700.0    29.31       178.57
# 233  Kieron Pollard            178.0     Mumbai  3268.0    29.98       149.77
# 165     Jofra Archer            35.0     Mumbai   195.0    15.00       157.26
# 211    Hardik Pandya            92.0    Gujarat  1476.0    27.33       153.91
# 128     Pat Cummins             37.0    Kolkata   316.0    19.75       140.44
# 218     Glen Maxwell            97.0  Bangalore  2018.0    25.23       151.84
# 223        Moeen Ali            34.0    Chennai   666.0    22.97       146.37
# 154       K Gowtham             24.0    Lucknow   186.0    14.31       169.09
# 195   Mohammad Nabi             17.0    Kolkata   180.0    15.00       151.26
# 202       Aman Khan              5.0    Kolkata    40.0    13.30       148.10
#
#     Nationality  Wickets  Bowling_average  Bowling_Strike_Rate  Economy
# 232    Overseas    143.0            24.53                21.83     6.74
# 204    Overseas     72.0            26.40                17.51     9.05
# 233    Overseas     65.0            31.62                21.60     8.78
# 165    Overseas     46.0            21.33                17.93     7.13
# 211      Indian     42.0            31.26                20.69     9.07
# 128    Overseas     38.0            30.13                21.95     8.24
# 218    Overseas     22.0            41.59                29.18     8.55
# 223    Overseas     16.0            29.31                25.69     6.85
# 154      Indian     13.0            43.23                31.38     8.26
# 195    Overseas     13.0            31.38                26.38     7.14
# 202      Indian      0.0             0.00                 0.00     7.00

# %%
top_allrounders_economy
# Out:
#          Player Name  Matches_Played       Team    Runs  Average  Strike_Rate  \
# 232    Sunil Narine            134.0    Kolkata   954.0    15.64       161.69
# 223        Moeen Ali            34.0    Chennai   666.0    22.97       146.37
# 202       Aman Khan              5.0    Kolkata    40.0    13.30       148.10
# 165     Jofra Archer            35.0     Mumbai   195.0    15.00       157.26
# 195   Mohammad Nabi             17.0    Kolkata   180.0    15.00       151.26
# 128     Pat Cummins             37.0    Kolkata   316.0    19.75       140.44
# 154       K Gowtham             24.0    Lucknow   186.0    14.31       169.09
# 218     Glen Maxwell            97.0  Bangalore  2018.0    25.23       151.84
# 233  Kieron Pollard            178.0     Mumbai  3268.0    29.98       149.77
# 204    Andre Russell            84.0    Kolkata  1700.0    29.31       178.57
# 211    Hardik Pandya            92.0    Gujarat  1476.0    27.33       153.91
#
#     Nationality  Wickets  Bowling_average  Bowling_Strike_Rate  Economy
# 232    Overseas    143.0            24.53                21.83     6.74
# 223    Overseas     16.0            29.31                25.69     6.85
# 202      Indian      0.0             0.00                 0.00     7.00
# 165    Overseas     46.0            21.33                17.93     7.13
# 195    Overseas     13.0            31.38                26.38     7.14
# 128    Overseas     38.0            30.13                21.95     8.24
# 154      Indian     13.0            43.23                31.38     8.26
# 218    Overseas     22.0            41.59                29.18     8.55
# 233    Overseas     65.0            31.62                21.60     8.78
# 204    Overseas     72.0            26.40                17.51     9.05
# 211      Indian     42.0            31.26                20.69     9.07

# %% [markdown]
# **#lets take 4 All-Rounders to make the top fantasy 11**
#
# 1. **Sunil Narine**
# 2. **Glenn Maxewell**
# 3. **Andre Russel**
# 4. **Hardik Pandya**

# %% [markdown]
# #**Keeper/s**

# %%
top_keepers= Capped_Keepers.loc[(Capped_Keepers["Average"]>=25.0)]
top_keepers_average=top_keepers.sort_values('Average',ascending=False)
top_keepers_runouts=top_keepers.sort_values('Run_outs',ascending=False)
top_keepers_catches=top_keepers.sort_values('Catches',ascending=False)
top_keepers_matches=top_keepers.sort_values('Matches_Played',ascending=False)
top_keepers_stumps=top_keepers.sort_values('Stumps',ascending=False)
top_keepers_strike_rate=top_keepers.sort_values('Strike_Rate',ascending=False)
top_keepers_runs=top_keepers.sort_values('Runs',ascending=False)

# %%
top_keepers_average
# Out:
#          Player Name  Matches_Played       Team    Runs  Average  Strike_Rate  \
# 108   Jonny Bairstow            28.0     Punjab  1038.0    41.50       142.20
# 213         MS Dhoni           220.0    Chennai  4746.0    39.50       135.80
# 111        KS Bharat             8.0      Delhi   191.0    38.20       122.40
# 206    Rishabh Pant             84.0      Delhi  2498.0    35.18       147.46
# 219       Jos Butler            65.0  Rajasthan  1968.0    35.14       150.00
# 105  Quinton De Kock            77.0    Lucknow  2256.0    31.30       130.90
# 106    Ambati Rayudu           175.0    Chennai  3916.0    29.40       127.50
# 209     Sanju Samson           121.0  Rajasthan  3068.0    29.22       134.21
# 107     Ishan Kishan            61.0     Mumbai  1452.0    28.50       136.30
# 109   Dinesh Karthik           213.0  Bangalore  4046.0    25.80       129.70
#
#     Nationality  Catches  Run_outs  Stumps
# 108    Overseas     18.0       1.0     4.0
# 213      Indian    126.0      21.0    39.0
# 111      Indian      4.0       0.0     1.0
# 206      Indian     56.0       5.0    14.0
# 219    Overseas     34.0       3.0     1.0
# 105    Overseas     53.0       0.0    14.0
# 106      Indian     58.0      12.0     2.0
# 209      Indian     59.0       8.0    10.0
# 107      Indian     19.0       1.0     2.0
# 109      Indian    123.0      14.0    32.0

# %%
top_keepers_runouts
# Out:
#          Player Name  Matches_Played       Team    Runs  Average  Strike_Rate  \
# 213         MS Dhoni           220.0    Chennai  4746.0    39.50       135.80
# 109   Dinesh Karthik           213.0  Bangalore  4046.0    25.80       129.70
# 106    Ambati Rayudu           175.0    Chennai  3916.0    29.40       127.50
# 209     Sanju Samson           121.0  Rajasthan  3068.0    29.22       134.21
# 206    Rishabh Pant             84.0      Delhi  2498.0    35.18       147.46
# 219       Jos Butler            65.0  Rajasthan  1968.0    35.14       150.00
# 107     Ishan Kishan            61.0     Mumbai  1452.0    28.50       136.30
# 108   Jonny Bairstow            28.0     Punjab  1038.0    41.50       142.20
# 105  Quinton De Kock            77.0    Lucknow  2256.0    31.30       130.90
# 111        KS Bharat             8.0      Delhi   191.0    38.20       122.40
#
#     Nationality  Catches  Run_outs  Stumps
# 213      Indian    126.0      21.0    39.0
# 109      Indian    123.0      14.0    32.0
# 106      Indian     58.0      12.0     2.0
# 209      Indian     59.0       8.0    10.0
# 206      Indian     56.0       5.0    14.0
# 219    Overseas     34.0       3.0     1.0
# 107      Indian     19.0       1.0     2.0
# 108    Overseas     18.0       1.0     4.0
# 105    Overseas     53.0       0.0    14.0
# 111      Indian      4.0       0.0     1.0

# %%
top_keepers_catches
# Out:
#          Player Name  Matches_Played       Team    Runs  Average  Strike_Rate  \
# 213         MS Dhoni           220.0    Chennai  4746.0    39.50       135.80
# 109   Dinesh Karthik           213.0  Bangalore  4046.0    25.80       129.70
# 209     Sanju Samson           121.0  Rajasthan  3068.0    29.22       134.21
# 106    Ambati Rayudu           175.0    Chennai  3916.0    29.40       127.50
# 206    Rishabh Pant             84.0      Delhi  2498.0    35.18       147.46
# 105  Quinton De Kock            77.0    Lucknow  2256.0    31.30       130.90
# 219       Jos Butler            65.0  Rajasthan  1968.0    35.14       150.00
# 107     Ishan Kishan            61.0     Mumbai  1452.0    28.50       136.30
# 108   Jonny Bairstow            28.0     Punjab  1038.0    41.50       142.20
# 111        KS Bharat             8.0      Delhi   191.0    38.20       122.40
#
#     Nationality  Catches  Run_outs  Stumps
# 213      Indian    126.0      21.0    39.0
# 109      Indian    123.0      14.0    32.0
# 209      Indian     59.0       8.0    10.0
# 106      Indian     58.0      12.0     2.0
# 206      Indian     56.0       5.0    14.0
# 105    Overseas     53.0       0.0    14.0
# 219    Overseas     34.0       3.0     1.0
# 107      Indian     19.0       1.0     2.0
# 108    Overseas     18.0       1.0     4.0
# 111      Indian      4.0       0.0     1.0

# %%
top_keepers_runs
# Out:
#          Player Name  Matches_Played       Team    Runs  Average  Strike_Rate  \
# 213         MS Dhoni           220.0    Chennai  4746.0    39.50       135.80
# 109   Dinesh Karthik           213.0  Bangalore  4046.0    25.80       129.70
# 106    Ambati Rayudu           175.0    Chennai  3916.0    29.40       127.50
# 209     Sanju Samson           121.0  Rajasthan  3068.0    29.22       134.21
# 206    Rishabh Pant             84.0      Delhi  2498.0    35.18       147.46
# 105  Quinton De Kock            77.0    Lucknow  2256.0    31.30       130.90
# 219       Jos Butler            65.0  Rajasthan  1968.0    35.14       150.00
# 107     Ishan Kishan            61.0     Mumbai  1452.0    28.50       136.30
# 108   Jonny Bairstow            28.0     Punjab  1038.0    41.50       142.20
# 111        KS Bharat             8.0      Delhi   191.0    38.20       122.40
#
#     Nationality  Catches  Run_outs  Stumps
# 213      Indian    126.0      21.0    39.0
# 109      Indian    123.0      14.0    32.0
# 106      Indian     58.0      12.0     2.0
# 209      Indian     59.0       8.0    10.0
# 206      Indian     56.0       5.0    14.0
# 105    Overseas     53.0       0.0    14.0
# 219    Overseas     34.0       3.0     1.0
# 107      Indian     19.0       1.0     2.0
# 108    Overseas     18.0       1.0     4.0
# 111      Indian      4.0       0.0     1.0

# %%
top_keepers_matches
# Out:
#          Player Name  Matches_Played       Team    Runs  Average  Strike_Rate  \
# 213         MS Dhoni           220.0    Chennai  4746.0    39.50       135.80
# 109   Dinesh Karthik           213.0  Bangalore  4046.0    25.80       129.70
# 106    Ambati Rayudu           175.0    Chennai  3916.0    29.40       127.50
# 209     Sanju Samson           121.0  Rajasthan  3068.0    29.22       134.21
# 206    Rishabh Pant             84.0      Delhi  2498.0    35.18       147.46
# 105  Quinton De Kock            77.0    Lucknow  2256.0    31.30       130.90
# 219       Jos Butler            65.0  Rajasthan  1968.0    35.14       150.00
# 107     Ishan Kishan            61.0     Mumbai  1452.0    28.50       136.30
# 108   Jonny Bairstow            28.0     Punjab  1038.0    41.50       142.20
# 111        KS Bharat             8.0      Delhi   191.0    38.20       122.40
#
#     Nationality  Catches  Run_outs  Stumps
# 213      Indian    126.0      21.0    39.0
# 109      Indian    123.0      14.0    32.0
# 106      Indian     58.0      12.0     2.0
# 209      Indian     59.0       8.0    10.0
# 206      Indian     56.0       5.0    14.0
# 105    Overseas     53.0       0.0    14.0
# 219    Overseas     34.0       3.0     1.0
# 107      Indian     19.0       1.0     2.0
# 108    Overseas     18.0       1.0     4.0
# 111      Indian      4.0       0.0     1.0

# %%
top_keepers_stumps
# Out:
#          Player Name  Matches_Played       Team    Runs  Average  Strike_Rate  \
# 213         MS Dhoni           220.0    Chennai  4746.0    39.50       135.80
# 109   Dinesh Karthik           213.0  Bangalore  4046.0    25.80       129.70
# 105  Quinton De Kock            77.0    Lucknow  2256.0    31.30       130.90
# 206    Rishabh Pant             84.0      Delhi  2498.0    35.18       147.46
# 209     Sanju Samson           121.0  Rajasthan  3068.0    29.22       134.21
# 108   Jonny Bairstow            28.0     Punjab  1038.0    41.50       142.20
# 106    Ambati Rayudu           175.0    Chennai  3916.0    29.40       127.50
# 107     Ishan Kishan            61.0     Mumbai  1452.0    28.50       136.30
# 111        KS Bharat             8.0      Delhi   191.0    38.20       122.40
# 219       Jos Butler            65.0  Rajasthan  1968.0    35.14       150.00
#
#     Nationality  Catches  Run_outs  Stumps
# 213      Indian    126.0      21.0    39.0
# 109      Indian    123.0      14.0    32.0
# 105    Overseas     53.0       0.0    14.0
# 206      Indian     56.0       5.0    14.0
# 209      Indian     59.0       8.0    10.0
# 108    Overseas     18.0       1.0     4.0
# 106      Indian     58.0      12.0     2.0
# 107      Indian     19.0       1.0     2.0
# 111      Indian      4.0       0.0     1.0
# 219    Overseas     34.0       3.0     1.0

# %%
top_keepers_strike_rate
# Out:
#          Player Name  Matches_Played       Team    Runs  Average  Strike_Rate  \
# 219       Jos Butler            65.0  Rajasthan  1968.0    35.14       150.00
# 206    Rishabh Pant             84.0      Delhi  2498.0    35.18       147.46
# 108   Jonny Bairstow            28.0     Punjab  1038.0    41.50       142.20
# 107     Ishan Kishan            61.0     Mumbai  1452.0    28.50       136.30
# 213         MS Dhoni           220.0    Chennai  4746.0    39.50       135.80
# 209     Sanju Samson           121.0  Rajasthan  3068.0    29.22       134.21
# 105  Quinton De Kock            77.0    Lucknow  2256.0    31.30       130.90
# 109   Dinesh Karthik           213.0  Bangalore  4046.0    25.80       129.70
# 106    Ambati Rayudu           175.0    Chennai  3916.0    29.40       127.50
# 111        KS Bharat             8.0      Delhi   191.0    38.20       122.40
#
#     Nationality  Catches  Run_outs  Stumps
# 219    Overseas     34.0       3.0     1.0
# 206      Indian     56.0       5.0    14.0
# 108    Overseas     18.0       1.0     4.0
# 107      Indian     19.0       1.0     2.0
# 213      Indian    126.0      21.0    39.0
# 209      Indian     59.0       8.0    10.0
# 105    Overseas     53.0       0.0    14.0
# 109      Indian    123.0      14.0    32.0
# 106      Indian     58.0      12.0     2.0
# 111      Indian      4.0       0.0     1.0

# %% [markdown]
# **# lets take 3 WK to make the top 11 fantasy**
#
# 1. **Jos Buttler**
# 2. **MS Dhoni**
# 3. **Rishab Pant**

# %% [markdown]
# # **Visualization for Enhanced Analysis**

# %%
plt.figure(figsize=(15,10))
sns.barplot(x='Player Name', y='Strike_Rate', data=top_batters)
#al-avg,run,sr,econ,wicke keep-avg,runs.sr,stumps,run_outs match played
# Out:
# <Axes: xlabel='Player Name', ylabel='Strike_Rate'>

# %%
plt.figure(figsize=(15,10))
sns.barplot(x='Player Name', y='Average', data=top_batters)
# Out:
# <Axes: xlabel='Player Name', ylabel='Average'>

# %%
plt.figure(figsize=(20,10))
sns.barplot(x='Player Name', y='Runs', data=top_batters)
# Out:
# <Axes: xlabel='Player Name', ylabel='Runs'>

# %%
plt.figure(figsize=(18,8))
sns.barplot(x='Player Name', y='Matches_Played', data=top_batters)
# Out:
# <Axes: xlabel='Player Name', ylabel='Matches_Played'>

# %%
plt.figure(figsize=(20,10))
sns.barplot(x='Player Name', y='Bowling_average', data=top_bowlers)
# Out:
# <Axes: xlabel='Player Name', ylabel='Bowling_average'>

# %%
plt.figure(figsize=(20,10))
sns.barplot(x='Player Name', y='Economy', data=top_bowlers)
# Out:
# <Axes: xlabel='Player Name', ylabel='Economy'>

# %%
plt.figure(figsize=(20,10))
sns.barplot(x='Player Name', y='Bowling_Strike_Rate', data=top_bowlers)
# Out:
# <Axes: xlabel='Player Name', ylabel='Bowling_Strike_Rate'>

# %%
plt.figure(figsize=(20,10))
sns.barplot(x='Player Name', y='Matches_Played', data=top_bowlers)
# Out:
# <Axes: xlabel='Player Name', ylabel='Matches_Played'>

# %%
plt.figure(figsize=(20,10))
sns.barplot(x='Player Name', y='Wickets', data=top_bowlers)
# Out:
# <Axes: xlabel='Player Name', ylabel='Wickets'>

# %%
plt.figure(figsize=(20,10))
sns.barplot(x='Player Name', y='Stumps', data=top_keepers)
# Out:
# <Axes: xlabel='Player Name', ylabel='Stumps'>

# %%
plt.figure(figsize=(20,5))
sns.barplot(x='Player Name', y='Run_outs', data=top_keepers)
# Out:
# <Axes: xlabel='Player Name', ylabel='Run_outs'>

# %%
plt.figure(figsize=(20,10))
sns.barplot(x='Player Name', y='Runs', data=top_keepers)
# Out:
# <Axes: xlabel='Player Name', ylabel='Runs'>

# %%
plt.figure(figsize=(20,8))
sns.barplot(x='Player Name', y='Runs', data=top_allrounders)
# Out:
# <Axes: xlabel='Player Name', ylabel='Runs'>

# %%
plt.figure(figsize=(20,8))
sns.barplot(x='Player Name', y='Strike_Rate', data=top_allrounders)
# Out:
# <Axes: xlabel='Player Name', ylabel='Strike_Rate'>

# %%
plt.figure(figsize=(20,8))
sns.barplot(x='Player Name', y='Average', data=top_allrounders)
# Out:
# <Axes: xlabel='Player Name', ylabel='Average'>

# %%
plt.figure(figsize=(20,8))
sns.barplot(x='Player Name', y='Economy', data=top_allrounders)
# Out:
# <Axes: xlabel='Player Name', ylabel='Economy'>

# %%
plt.figure(figsize=(20,8))
sns.barplot(x='Player Name', y='Bowling_Strike_Rate', data=top_allrounders)
# Out:
# <Axes: xlabel='Player Name', ylabel='Bowling_Strike_Rate'>

# %%
plt.figure(figsize=(20,8))
sns.barplot(x='Player Name', y='Wickets', data=top_allrounders)
# Out:
# <Axes: xlabel='Player Name', ylabel='Wickets'>

# %% [markdown]
# # **Fantasy 11**

# %%
#Batters

top_batters.reset_index(drop=True)
matches_values=[top_batters.iloc[6]['Matches_Played'], top_batters.iloc[2]['Matches_Played'],top_batters.iloc[5]['Matches_Played']]
runs_values=[top_batters.iloc[6]['Runs'], top_batters.iloc[2]['Runs'],top_batters.iloc[5]['Runs']]
average_values=[top_batters.iloc[6]['Average'], top_batters.iloc[2]['Average'],top_batters.iloc[5]['Average']]
Strike_rate_values=[top_batters.iloc[6]['Strike_Rate'], top_batters.iloc[2]['Strike_Rate'],top_batters.iloc[5]['Strike_Rate']]

Labels=['Ruturaj Gaikwad','David Warner','Virat Kohli']

fig, axes=plt.subplots(2,2,figsize=(10,10))
axes[0][0].set_title("Matches Played")
axes[0][1].set_title("Runs in the IPL")
axes[1][0].set_title("Strike Rate")
axes[1][1].set_title("Average")
sns.barplot(x=Labels, y=matches_values,ax=axes[0][0])
sns.barplot(x=Labels, y=runs_values,ax=axes[0][1])
sns.barplot(x=Labels, y=Strike_rate_values,ax=axes[1][0])
sns.barplot(x=Labels, y=average_values,ax=axes[1][1])
# Out:
# <Axes: title={'center': 'Average'}>

# %%
# All-Rounders

top_allrounders.reset_index(drop=True)
matches_values=[top_allrounders.iloc[5]['Matches_Played'],top_allrounders.iloc[9]['Matches_Played'],top_allrounders.iloc[6]['Matches_Played']]
runs_values=[top_allrounders.iloc[5]['Runs'],top_allrounders.iloc[9]['Runs'],top_allrounders.iloc[6]['Runs']]
average=[top_allrounders.iloc[5]['Average'],top_allrounders.iloc[9]['Average'],top_allrounders.iloc[6]['Average']]
strike_rate_values=[top_allrounders.iloc[5]['Strike_Rate'],top_allrounders.iloc[9]['Strike_Rate'],top_allrounders.iloc[6]['Strike_Rate']]
bowling_strike_rate_values=[top_allrounders.iloc[5]['Bowling_Strike_Rate'],top_allrounders.iloc[9]['Bowling_Strike_Rate'],top_allrounders.iloc[6]['Bowling_Strike_Rate']]
bowling_average_values=[top_allrounders.iloc[5]['Bowling_average'],top_allrounders.iloc[9]['Bowling_average'],top_allrounders.iloc[6]['Bowling_average']]
wickets_values=[top_allrounders.iloc[5]['Wickets'],top_allrounders.iloc[9]['Wickets'],top_allrounders.iloc[6]['Wickets']]
economy_values=[top_allrounders.iloc[5]['Economy'],top_allrounders.iloc[9]['Economy'],top_allrounders.iloc[6]['Economy']]


Labels=['Glenn Maxewell','Hardik Pandya','Andre Russell']
fig,axes=plt.subplots(4,2,figsize=(20,20))
axes[0][0].set_title("Matches")
axes[0][1].set_title("Runs")
axes[1][0].set_title("Average")
axes[1][1].set_title("Strike_Rate")
axes[2][0].set_title("Bowling_Strike_Rate")
axes[2][1].set_title("Bowling_average")
axes[3][0].set_title("Wickets")
axes[3][1].set_title("Economy")


sns.barplot(x=Labels,y=matches_values,ax=axes[0][0])
sns.barplot(x=Labels,y=runs_values,ax=axes[0][1])
sns.barplot(x=Labels,y=strike_rate_values,ax=axes[1][0])
sns.barplot(x=Labels,y=strike_rate_values,ax=axes[1][1])
sns.barplot(x=Labels,y=bowling_strike_rate_values,ax=axes[2][0])
sns.barplot(x=Labels,y=bowling_average_values,ax=axes[2][1])
sns.barplot(x=Labels,y=wickets_values,ax=axes[3][0])
sns.barplot(x=Labels,y=economy_values,ax=axes[3][1])
# Out:
# <Axes: title={'center': 'Economy'}>

# %%
# Bowlers



top_bowlers.reset_index(drop=True)
matches_values=[top_bowlers.iloc[10]['Matches_Played'],top_bowlers.iloc[0]['Matches_Played'],top_bowlers.iloc[8]['Matches_Played'],top_bowlers.iloc[1]['Matches_Played']]
wickets_values=[top_bowlers.iloc[10]['Wickets'],top_bowlers.iloc[0]['Wickets'],top_bowlers.iloc[8]['Wickets'],top_bowlers.iloc[1]['Wickets']]
bowling_average_values=[top_bowlers.iloc[10]['Bowling_average'],top_bowlers.iloc[0]['Bowling_average'],top_bowlers.iloc[8]['Bowling_average'],top_bowlers.iloc[1]['Bowling_average']]
bowling_strike_rate_values=[top_bowlers.iloc[10]['Bowling_Strike_Rate'],top_bowlers.iloc[0]['Bowling_Strike_Rate'],top_bowlers.iloc[8]['Bowling_Strike_Rate'],top_bowlers.iloc[1]['Bowling_Strike_Rate']]
economy_values=[top_bowlers.iloc[10]['Economy'],top_bowlers.iloc[0]['Economy'],top_bowlers.iloc[8]['Economy'],top_bowlers.iloc[1]['Economy']]

Labels=['Kagiso Rabada','Arshdeep Singh','Jasprit Bumrah','Yuzvendra Chahal']
fig,axes=plt.subplots(3,2,figsize=(15,15))
axes[0][0].set_title("Matches_Played")
axes[0][1].set_title("Wickets")
axes[1][0].set_title("Bowling_Average")
axes[1][1].set_title("Bowling_Strike_Rate")
axes[2][0].set_title("Economy")
sns.barplot(x=Labels,y=matches_values,ax=axes[0][0])
sns.barplot(x=Labels,y=wickets_values,ax=axes[0][1])
sns.barplot(x=Labels,y=wickets_values,ax=axes[1][0])
sns.barplot(x=Labels,y=bowling_average_values,ax=axes[1][1])
sns.barplot(x=Labels,y=economy_values,ax=axes[2][0])
# Out:
# <Axes: title={'center': 'Economy'}>

# %%
#Keeper

matches_values=[top_keepers.iloc[8]['Matches_Played'],top_keepers.iloc[8]['Runs']]
average_values=[top_keepers.iloc[8]['Average'],top_keepers.iloc[8]['Strike_Rate']]
keeping_values=[top_keepers.iloc[8]['Catches'],top_keepers.iloc[8]['Stumps'],top_keepers.iloc[8]['Run_outs']]
label1=['Matches','Runs']
label2=['Average','Strike Rate']
label3=['Catches','Stumps','Runs-outs']

fig,axes=plt.subplots(1,3,figsize=(20,10))
axes[0].set_title("Matches and Runs")
axes[1].set_title("Average and Strike Rate")
axes[2].set_title("Keeping Stats")

sns.barplot(x=label1, y=matches_values,ax=axes[0])
sns.barplot(x=label2, y=average_values,ax=axes[1])
sns.barplot(x=label3, y=keeping_values,ax=axes[2])
# Out:
# <Axes: title={'center': 'Keeping Stats'}>

# %% [markdown]
# #**Final 11**

# %%
batter1=top_batters.loc[(top_batters["Player Name"]== 'David Warner ')]
batter2=top_batters.loc[(top_batters["Player Name"]== 'KL Rahul ')]
batter3=top_batters.loc[(top_batters["Player Name"]== 'Virat Kohli')]

bowler1=top_bowlers.loc[(top_bowlers["Player Name"]== 'Jasprit Bumrah')]
bowler2=top_bowlers.loc[(top_bowlers["Player Name"]== 'Kagiso Rabada ')]
bowler3=top_bowlers.loc[(top_bowlers["Player Name"]== 'Arshdeep Singh ')]
bowler4=top_bowlers.loc[(top_bowlers["Player Name"]== 'Yuzvendra Chahal ')]

allrounder1=top_allrounders.loc[(top_allrounders["Player Name"]== 'Glen Maxwell')]
allrounder2=top_allrounders.loc[(top_allrounders["Player Name"]== 'Hardik Pandya')]
allrounder3=top_allrounders.loc[(top_allrounders["Player Name"]== 'Andre Russell')]


keeper=top_keepers.loc[(top_keepers["Player Name"]== 'MS Dhoni')]

# %%
final=[batter1,batter2,batter3,allrounder1,allrounder2,allrounder3,keeper,bowler1, bowler2, bowler3, bowler4]
final_team=pd.concat(final)
final_team=final_team.drop(labels=['Matches_Played' , 'Runs' , 'Average' , 'Strike_Rate' , 'Wickets' , 'Bowling_average' ,
                                   'Economy', 'Bowling_Strike_Rate' , 'Catches' , 'Run_outs' , 'Stumps'],axis=1)
final_team.reset_index(drop=True)
# Out:
#           Player Name       Team Nationality
# 0       David Warner       Delhi    Overseas
# 1           KL Rahul     Lucknow      Indian
# 2         Virat Kohli  Bangalore      Indian
# 3        Glen Maxwell  Bangalore    Overseas
# 4       Hardik Pandya    Gujarat      Indian
# 5       Andre Russell    Kolkata    Overseas
# 6            MS Dhoni    Chennai      Indian
# 7      Jasprit Bumrah     Mumbai      Indian
# 8      Kagiso Rabada      Punjab    Overseas
# 9     Arshdeep Singh      Punjab      Indian
# 10  Yuzvendra Chahal   Rajasthan      Indian
